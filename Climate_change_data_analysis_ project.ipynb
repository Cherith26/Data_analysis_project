# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Dell\Downloads\climate_change_indicators.csv")

# %%
data.head(3)
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# 2  Food and Agriculture Organization of the Unite...     ECCS
#
#                      CTS_Name  \
# 0  Surface Temperature Change
# 1  Surface Temperature Change
# 2  Surface Temperature Change
#
#                                  CTS_Full_Descriptor  ...  F2013  F2014  \
# ...

# %%
data.shape
# Out:
# (225, 72)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=225, step=1)

# %%
data.columns
# Out:
# Index(['ObjectId', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source',
#        'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', 'F1961', 'F1962',
#        'F1963', 'F1964', 'F1965', 'F1966', 'F1967', 'F1968', 'F1969', 'F1970',
#        'F1971', 'F1972', 'F1973', 'F1974', 'F1975', 'F1976', 'F1977', 'F1978',
#        'F1979', 'F1980', 'F1981', 'F1982', 'F1983', 'F1984', 'F1985', 'F1986',
#        'F1987', 'F1988', 'F1989', 'F1990', 'F1991', 'F1992', 'F1993', 'F1994',
#        'F1995', 'F1996', 'F1997', 'F1998', 'F1999', 'F2000', 'F2001', 'F2002',
#        'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009', 'F2010',
#        'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018',
#        'F2019', 'F2020', 'F2021', 'F2022'],
#       dtype='object')

# %%
data.dtypes
# Out:
# ObjectId       int64
# Country       object
# ISO2          object
# ISO3          object
# Indicator     object
#               ...
# F2018        float64
# F2019        float64
# F2020        float64
# F2021        float64
# F2022        float64
# Length: 72, dtype: object

# %%
data.nunique()
# Out:
# ObjectId     225
# Country      225
# ISO2         223
# ISO3         225
# Indicator      1
#             ...
# F2018        200
# F2019        197
# F2020        196
# F2021        198
# F2022        206
# Length: 72, dtype: int64

# %%
data.groupby('Country')['Unit'].sum().sort_values(ascending=False).head(10)
# Out:
# Country
# Afghanistan, Islamic Rep. of     Degree Celsius
# Libya                            Degree Celsius
# New Zealand                      Degree Celsius
# Nicaragua                        Degree Celsius
# Niger                            Degree Celsius
# Nigeria                          Degree Celsius
# Niue                             Degree Celsius
# Norfolk Island                   Degree Celsius
# North Macedonia, Republic of     Degree Celsius
# Norway                           Degree Celsius
# Name: Unit, dtype: object

# %%
data.groupby('Indicator')['F2018'].sum().sort_values(ascending=True).head(10)
# Out:
# Indicator
# Temperature change with respect to a baseline climatology, corresponding to the period 1951-1980    277.35
# Name: F2018, dtype: float64

# %%
data.F2018<1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 220     True
# 221    False
# 222    False
# 223     True
# 224     True
# Name: F2018, Length: 225, dtype: bool

# %%
df = pd.DataFrame(data)

# Plotting
df.plot(kind='bar', x='Unit', y='F2018', color='skyblue', legend=None)
plt.xlabel('Unit')
plt.ylabel('F2018')
plt.title('F2018 by Unit')
plt.show()

# %%
data = pd.DataFrame(data)

# Plotting
df.plot(kind='line', x='Unit', y='F2018', marker='o', color='green')
plt.xlabel('Unit')
plt.ylabel('F2018')
plt.title('F2018 by Unit')
plt.grid(True)
plt.show()

# %%
data = pd.DataFrame(data)

# Count occurrences of each country
country_counts = df['Country'].value_counts()

# Count occurrences of each unit
unit_counts = df['Unit'].value_counts()

# Plotting the pie chart for Country
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.pie(country_counts, labels=country_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution by Country')
# Plotting the pie chart for Unit
plt.subplot(1, 2, 2)
plt.pie(unit_counts, labels=unit_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution by Unit')

plt.show()
